# %%
import sys
import os

project_root = os.path.abspath('..')
if project_root not in sys.path:
    sys.path.append(project_root)
 
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
import pandas as pd
import numpy as np

import matplotlib.pyplot as plt
import seaborn as sns

sns.set_theme(palette='pastel')
plt.rcParams['figure.figsize'] = (12, 6)
pd.set_option('display.max_columns', None)

# %%
df = pd.read_csv("../data/interim/resumen_egresos_nacionales.csv")

# %%
df = df.sort_values(["ANO_EGRESO", "DIAG1", "n_egresos"], ascending=False)

# %%
df["ranking_recinto"] = df.groupby(["ANO_EGRESO", "DIAG1"])["n_egresos"].rank(ascending=False, method="min")

# %%
df
# Out:
#          ANO_EGRESO  ESTABLECIMIENTO_SALUD  \
# 3185250      2020.0               104103.0
# 3183419      2020.0               125102.0
# 1814342      2020.0               125103.0
# 675224       2020.0               118106.0
# 2047483      2020.0               102200.0
# ...             ...                    ...
# 1367500      2001.0               115110.0
# 1597862      2001.0               111200.0
# 1825513      2001.0               112100.0
# 2741207      2001.0               113180.0
# 10952           NaN                    NaN
#
#                                GLOSA_ESTABLECIMIENTO_SALUD  \
# 3185250  Hospital Provincial del Huasco Monseñor Fernan...
# 3183419      Hospital Dr. Leopoldo Ortega R. (Chile Chico)
# 1814342                             Hospital Lord Cochrane
# 675224                                    Hospital de Lota
# 2047483                                   Clínica Iquique
# ...                                                    ...
# ...
